# %%
from openfermion import MolecularData
from openfermionpyscf import run_pyscf
from openfermion.ops import FermionOperator, QubitOperator
from openfermion.transforms import jordan_wigner, bravyi_kitaev
from openfermion.transforms import get_fermion_operator
from openfermion.circuits import (uccsd_singlet_get_packed_amplitudes,
                               uccsd_singlet_generator, uccsd_generator,
                               uccsd_convert_amplitude_format)
from pathlib import Path
import qreduce.qonversion_tools as qonvert

geom_path = Path("data/molecule_geometries/water.xyz").absolute()
# Out:
# Will store matrices in sparse form
# /home/tweaving/.local/lib/python3.8/site-packages/qiskit/aqua/__init__.py:86: DeprecationWarning: The package qiskit.aqua is deprecated. It was moved/refactored to qiskit-terra For more information see <https://github.com/Qiskit/qiskit-aqua/blob/main/README.md#migration-guide>
#   warn_package('aqua', 'qiskit-terra')

# %%
# define molecule parameters
geometry = []
xyz = open(geom_path, 'r')
n_atoms = int(xyz.readline())
title = xyz.readline()
for line in xyz:
    atom,x,y,z = line.split()
    geometry.append((atom, (float(x), float(y), float(z))))
xyz.close()

basis = 'sto-3g'
multiplicity = 1
charge = 0

# Make molecule
molecule_data = MolecularData(geometry, basis, multiplicity, charge)

# %%
singlet_bool=True

# Set calculation parameters.
run_scf = 1
run_mp2 = 1
run_cisd = 1
run_ccsd = 1
run_fci = 1
delete_input = True
delete_output = True

# Run pyscf.
molecule = run_pyscf(molecule_data,
                     run_scf=run_scf,
                     run_mp2=run_mp2,
                     run_cisd=run_cisd,
                     run_ccsd=run_ccsd,
                     run_fci=run_fci)

#molecule.load()
#print(molecule)

ham_f = get_fermion_operator(molecule.get_molecular_hamiltonian())
ham_q = jordan_wigner(ham_f)

ccsd_single_amps = molecule.ccsd_single_amps
ccsd_double_amps = molecule.ccsd_double_amps
num_electrons = molecule.n_electrons
num_qubits = 2*molecule.n_orbitals

if singlet_bool:
    # Get singlet UCCSD generator.
    packed_amps = uccsd_singlet_get_packed_amplitudes(ccsd_single_amps,  ccsd_double_amps, num_qubits, num_electrons)
    ucc_op = uccsd_singlet_generator(packed_amps, num_qubits, num_electrons)
    #print(ucc_sing)

else:
    # Get general UCCSD operator.
    ucc_op = uccsd_generator(ccsd_single_amps, ccsd_double_amps)
    #print(ucc_op)
    
ucc_q = jordan_wigner(ucc_op)

ham = qonvert.QubitOperator_to_dict(ham_q, num_qubits)
ucc = qonvert.QubitOperator_to_dict(ucc_q, num_qubits)

# %%
ucc
# Out:
# {'YZZZZZZZZZXIII': -1.5802759310044073e-05j,
#  'XZZZZZZZZZYIII': 1.5802759310044073e-05j,
#  'YYIIIIIIIIYXII': -8.085781840681895e-05j,
#  'YXIIIIIIIIYYII': 8.085781840681895e-05j,
#  'XXIIIIIIIIYXII': 8.085781840681895e-05j,
#  'XYIIIIIIIIYYII': 8.085781840681895e-05j,
#  'YXIIIIIIIIXXII': -8.085781840681895e-05j,
#  'YYIIIIIIIIXYII': -8.085781840681895e-05j,
#  'XYIIIIIIIIXXII': -8.085781840681895e-05j,
#  'XXIIIIIIIIXYII': 8.085781840681895e-05j,
#  'IYZZZZZZZZZXII': -1.5802759310044073e-05j,
#  'IXZZZZZZZZZYII': 1.5802759310044073e-05j,
#  'IIYZZZZZZZXIII': 0.0001063155681063989j,
#  'IIXZZZZZZZYIII': -0.0001063155681063989j,
#  'IIYYIIIIIIYXII': -0.004056869567615022j,
#  'IIYXIIIIIIYYII': 0.004056869567615022j,
#  'IIXXIIIIIIYXII': 0.004056869567615022j,
#  'IIXYIIIIIIYYII': 0.004056869567615022j,
#  'IIYXIIIIIIXXII': -0.004056869567615022j,
#  'IIYYIIIIIIXYII': -0.004056869567615022j,
#  'IIXYIIIIIIXXII': -0.004056869567615022j,
#  'IIXXIIIIIIXYII': 0.004056869567615022j,
#  'IIIYZZZZZZZXII': 0.0001063155681063989j,
#  'IIIXZZZZZZZYII': -0.0001063155681063989j,
#  'IIIIYYIIIIYXII': -0.00541245255780436j,
#  'IIIIYXIIIIYYII': 0.00541245255780436j,
#  'IIIIXXIIIIYXII': 0.00541245255780436j,
#  'IIIIXYIIIIYYII': 0.00541245255780436j,
#  'IIIIYXIIIIXXII': -0.00541245255780436j,
#  'IIIIYYIIIIXYII': -0.00541245255780436j,
#  'IIIIXYIIIIXXII': -0.00541245255780436j,
#  'IIIIXXIIIIXYII': 0.00541245255780436j,
#  'IIIIIIYZZZXIII': 0.006618834269774724j,
#  'IIIIIIXZZZYIII': -0.006618834269774724j,
#  'IIIIIIYYIIYXII': -0.0060109708316462675j,
#  'IIIIIIYXIIYYII': 0.0060109708316462675j,
#  'IIIIIIXXIIYXII': 0.0060109708316462675j,
#  'IIIIIIXYIIYYII': 0.0060109708316462675j,
#  'IIIIIIYXIIXXII': -0.0060109708316462675j,
#  'IIIIIIYYIIXYII': -0.0060109708316462675j,
#  'IIIIIIXYIIXXII': -0.0060109708316462675j,
#  'IIIIIIXXIIXYII': 0.0060109708316462675j,
#  'IIIIIIIYZZZXII': 0.006618834269774724j,
#  'IIIIIIIXZZZYII': -0.006618834269774724j,
#  'IIIIIIIIYYYXII': -0.0032467465249087423j,
#  'IIIIIIIIYXYYII': 0.0032467465249087423j,
#  'IIIIIIIIXXYXII': 0.0032467465249087423j,
#  'IIIIIIIIXYYYII': 0.0032467465249087423j,
#  'IIIIIIIIYXXXII': -0.0032467465249087423j,
#  'IIIIIIIIYYXYII': -0.0032467465249087423j,
#  'IIIIIIIIXYXXII': -0.0032467465249087423j,
#  'IIIIIIIIXXXYII': 0.0032467465249087423j,
#  'YYIIIIIIIIIIYX': -5.194592728253943e-05j,
#  'YXIIIIIIIIIIYY': 5.194592728253943e-05j,
#  'XXIIIIIIIIIIYX': 5.194592728253943e-05j,
#  'XYIIIIIIIIIIYY': 5.194592728253943e-05j,
#  'YXIIIIIIIIIIXX': -5.194592728253943e-05j,
#  'YYIIIIIIIIIIXY': -5.194592728253943e-05j,
#  'XYIIIIIIIIIIXX': -5.194592728253943e-05j,
#  'XXIIIIIIIIIIXY': 5.194592728253943e-05j,
#  'IIYYIIIIIIIIYX': -0.0020766531022052446j,
#  'IIYXIIIIIIIIYY': 0.0020766531022052446j,
#  'IIXXIIIIIIIIYX': 0.0020766531022052446j,
#  'IIXYIIIIIIIIYY': 0.0020766531022052446j,
#  'IIYXIIIIIIIIXX': -0.0020766531022052446j,
#  'IIYYIIIIIIIIXY': -0.0020766531022052446j,
#  'IIXYIIIIIIIIXX': -0.0020766531022052446j,
#  'IIXXIIIIIIIIXY': 0.0020766531022052446j,
#  'IIIIYZZZZZZZXI': -0.0017148883739077875j,
#  'IIIIXZZZZZZZYI': 0.0017148883739077875j,
#  'IIIIYYIIIIIIYX': -0.010032042840523435j,
#  'IIIIYXIIIIIIYY': 0.010032042840523435j,
#  'IIIIXXIIIIIIYX': 0.010032042840523435j,
#  'IIIIXYIIIIIIYY': 0.010032042840523435j,
#  'IIIIYXIIIIIIXX': -0.010032042840523435j,
#  'IIIIYYIIIIIIXY': -0.010032042840523435j,
#  'IIIIXYIIIIIIXX': -0.010032042840523435j,
#  'IIIIXXIIIIIIXY': 0.010032042840523435j,
#  'IIIIIYZZZZZZZX': -0.0017148883739077875j,
#  'IIIIIXZZZZZZZY': 0.0017148883739077875j,
#  'IIIIIIYYIIIIYX': -0.005402834019777595j,
#  'IIIIIIYXIIIIYY': 0.005402834019777595j,
#  'IIIIIIXXIIIIYX': 0.005402834019777595j,
#  'IIIIIIXYIIIIYY': 0.005402834019777595j,
#  'IIIIIIYXIIIIXX': -0.005402834019777595j,
#  'IIIIIIYYIIIIXY': -0.005402834019777595j,
#  'IIIIIIXYIIIIXX': -0.005402834019777595j,
#  'IIIIIIXXIIIIXY': 0.005402834019777595j,
#  'IIIIIIIIYYIIYX': -0.0013272524785466159j,
#  'IIIIIIIIYXIIYY': 0.0013272524785466159j,
#  'IIIIIIIIXXIIYX': 0.0013272524785466159j,
#  'IIIIIIIIXYIIYY': 0.0013272524785466159j,
#  'IIIIIIIIYXIIXX': -0.0013272524785466159j,
#  'IIIIIIIIYYIIXY': -0.0013272524785466159j,
#  'IIIIIIIIXYIIXX': -0.0013272524785466159j,
#  'IIIIIIIIXXIIXY': 0.0013272524785466159j,
#  'YZZZYIIIIIYZXI': 6.062024918508203e-05j,
#  'YZZZXIIIIIYZYI': -6.062024918508203e-05j,
#  'XZZZXIIIIIYZXI': -6.062024918508203e-05j,
#  'XZZZYIIIIIYZYI': -6.062024918508203e-05j,
#  'YZZZXIIIIIXZXI': 6.062024918508203e-05j,
#  'YZZZYIIIIIXZYI': 6.062024918508203e-05j,
#  'XZZZYIIIIIXZXI': 6.062024918508203e-05j,
#  'XZZZXIIIIIXZYI': -6.062024918508203e-05j,
#  'YZZZZYIIIIYZZX': 3.0310124592541016e-05j,
#  'YZZZZXIIIIYZZY': -3.0310124592541016e-05j,
#  'XZZZZXIIIIYZZX': -3.0310124592541016e-05j,
#  'XZZZZYIIIIYZZY': -3.0310124592541016e-05j,
#  'YZZZZXIIIIXZZX': 3.0310124592541016e-05j,
#  'YZZZZYIIIIXZZY': 3.0310124592541016e-05j,
#  'XZZZZYIIIIXZZX': 3.0310124592541016e-05j,
#  'XZZZZXIIIIXZZY': -3.0310124592541016e-05j,
#  'IYZZYIIIIIIYXI': 3.0310124592541016e-05j,
#  'IYZZXIIIIIIYYI': -3.0310124592541016e-05j,
#  'IXZZXIIIIIIYXI': -3.0310124592541016e-05j,
#  'IXZZYIIIIIIYYI': -3.0310124592541016e-05j,
#  'IYZZXIIIIIIXXI': 3.0310124592541016e-05j,
#  'IYZZYIIIIIIXYI': 3.0310124592541016e-05j,
#  'IXZZYIIIIIIXXI': 3.0310124592541016e-05j,
#  'IXZZXIIIIIIXYI': -3.0310124592541016e-05j,
#  'IYZZZYIIIIIYZX': 6.062024918508203e-05j,
#  'IYZZZXIIIIIYZY': -6.062024918508203e-05j,
#  'IXZZZXIIIIIYZX': -6.062024918508203e-05j,
#  'IXZZZYIIIIIYZY': -6.062024918508203e-05j,
#  'IYZZZXIIIIIXZX': 6.062024918508203e-05j,
#  'IYZZZYIIIIIXZY': 6.062024918508203e-05j,
#  'IXZZZYIIIIIXZX': 6.062024918508203e-05j,
#  'IXZZZXIIIIIXZY': -6.062024918508203e-05j,
#  'IIYZYIIIIIYZXI': -0.0013109792900075118j,
#  'IIYZXIIIIIYZYI': 0.0013109792900075118j,
#  'IIXZXIIIIIYZXI': 0.0013109792900075118j,
#  'IIXZYIIIIIYZYI': 0.0013109792900075118j,
#  'IIYZXIIIIIXZXI': -0.0013109792900075118j,
#  'IIYZYIIIIIXZYI': -0.0013109792900075118j,
#  'IIXZYIIIIIXZXI': -0.0013109792900075118j,
#  'IIXZXIIIIIXZYI': 0.0013109792900075118j,
#  'IIYZZYIIIIYZZX': -0.0006554896450037559j,
#  'IIYZZXIIIIYZZY': 0.0006554896450037559j,
#  'IIXZZXIIIIYZZX': 0.0006554896450037559j,
#  'IIXZZYIIIIYZZY': 0.0006554896450037559j,
#  'IIYZZXIIIIXZZX': -0.0006554896450037559j,
#  'IIYZZYIIIIXZZY': -0.0006554896450037559j,
#  'IIXZZYIIIIXZZX': -0.0006554896450037559j,
#  'IIXZZXIIIIXZZY': 0.0006554896450037559j,
#  'IIIYYIIIIIIYXI': -0.0006554896450037559j,
#  'IIIYXIIIIIIYYI': 0.0006554896450037559j,
#  'IIIXXIIIIIIYXI': 0.0006554896450037559j,
#  'IIIXYIIIIIIYYI': 0.0006554896450037559j,
#  'IIIYXIIIIIIXXI': -0.0006554896450037559j,
#  'IIIYYIIIIIIXYI': -0.0006554896450037559j,
#  'IIIXYIIIIIIXXI': -0.0006554896450037559j,
#  'IIIXXIIIIIIXYI': 0.0006554896450037559j,
#  'IIIYZYIIIIIYZX': -0.0013109792900075118j,
#  'IIIYZXIIIIIYZY': 0.0013109792900075118j,
#  'IIIXZXIIIIIYZX': 0.0013109792900075118j,
#  'IIIXZYIIIIIYZY': 0.0013109792900075118j,
#  'IIIYZXIIIIIXZX': -0.0013109792900075118j,
#  'IIIYZYIIIIIXZY': -0.0013109792900075118j,
#  'IIIXZYIIIIIXZX': -0.0013109792900075118j,
#  'IIIXZXIIIIIXZY': 0.0013109792900075118j,
#  'IXZZXIIIIIYZZX': -3.0310124592541016e-05j,
#  'IYZZXIIIIIYZZY': -3.0310124592541016e-05j,
#  'IYZZYIIIIIYZZX': 3.0310124592541016e-05j,
#  'IXZZYIIIIIYZZY': -3.0310124592541016e-05j,
#  'IYZZXIIIIIXZZX': 3.0310124592541016e-05j,
#  'IXZZXIIIIIXZZY': -3.0310124592541016e-05j,
#  'IXZZYIIIIIXZZX': 3.0310124592541016e-05j,
#  'IYZZYIIIIIXZZY': 3.0310124592541016e-05j,
#  'XZZZZXIIIIIYXI': -3.0310124592541016e-05j,
#  'YZZZZXIIIIIYYI': -3.0310124592541016e-05j,
#  'YZZZZYIIIIIYXI': 3.0310124592541016e-05j,
#  'XZZZZYIIIIIYYI': -3.0310124592541016e-05j,
#  'YZZZZXIIIIIXXI': 3.0310124592541016e-05j,
#  'XZZZZXIIIIIXYI': -3.0310124592541016e-05j,
#  'XZZZZYIIIIIXXI': 3.0310124592541016e-05j,
#  'YZZZZYIIIIIXYI': 3.0310124592541016e-05j,
#  'IIIXXIIIIIYZZX': 0.0006554896450037559j,
#  'IIIYXIIIIIYZZY': 0.0006554896450037559j,
#  'IIIYYIIIIIYZZX': -0.0006554896450037559j,
#  'IIIXYIIIIIYZZY': 0.0006554896450037559j,
#  'IIIYXIIIIIXZZX': -0.0006554896450037559j,
#  'IIIXXIIIIIXZZY': 0.0006554896450037559j,
#  'IIIXYIIIIIXZZX': -0.0006554896450037559j,
#  'IIIYYIIIIIXZZY': -0.0006554896450037559j,
#  'IIXZZXIIIIIYXI': 0.0006554896450037559j,
#  'IIYZZXIIIIIYYI': 0.0006554896450037559j,
#  'IIYZZYIIIIIYXI': -0.0006554896450037559j,
#  'IIXZZYIIIIIYYI': 0.0006554896450037559j,
#  'IIYZZXIIIIIXXI': -0.0006554896450037559j,
#  'IIXZZXIIIIIXYI': 0.0006554896450037559j,
#  'IIXZZYIIIIIXXI': -0.0006554896450037559j,
#  'IIYZZYIIIIIXYI': -0.0006554896450037559j,
#  'IIIIYZYIIIYZXI': -0.0017075134479304973j,
#  'IIIIYZXIIIYZYI': 0.0017075134479304973j,
#  'IIIIXZXIIIYZXI': 0.0017075134479304973j,
#  'IIIIXZYIIIYZYI': 0.0017075134479304973j,
#  'IIIIYZXIIIXZXI': -0.0017075134479304973j,
#  'IIIIYZYIIIXZYI': -0.0017075134479304973j,
#  'IIIIXZYIIIXZXI': -0.0017075134479304973j,
#  'IIIIXZXIIIXZYI': 0.0017075134479304973j,
#  'IIIIYZZYIIYZZX': -0.0008537567239652486j,
#  'IIIIYZZXIIYZZY': 0.0008537567239652486j,
#  'IIIIXZZXIIYZZX': 0.0008537567239652486j,
#  'IIIIXZZYIIYZZY': 0.0008537567239652486j,
#  'IIIIYZZXIIXZZX': -0.0008537567239652486j,
#  'IIIIYZZYIIXZZY': -0.0008537567239652486j,
#  'IIIIXZZYIIXZZX': -0.0008537567239652486j,
#  'IIIIXZZXIIXZZY': 0.0008537567239652486j,
#  'IIIIIYYIIIIYXI': -0.0008537567239652486j,
#  'IIIIIYXIIIIYYI': 0.0008537567239652486j,
#  'IIIIIXXIIIIYXI': 0.0008537567239652486j,
#  'IIIIIXYIIIIYYI': 0.0008537567239652486j,
#  'IIIIIYXIIIIXXI': -0.0008537567239652486j,
#  'IIIIIYYIIIIXYI': -0.0008537567239652486j,
#  'IIIIIXYIIIIXXI': -0.0008537567239652486j,
#  'IIIIIXXIIIIXYI': 0.0008537567239652486j,
#  'IIIIIYZYIIIYZX': -0.0017075134479304973j,
#  'IIIIIYZXIIIYZY': 0.0017075134479304973j,
#  'IIIIIXZXIIIYZX': 0.0017075134479304973j,
#  'IIIIIXZYIIIYZY': 0.0017075134479304973j,
#  'IIIIIYZXIIIXZX': -0.0017075134479304973j,
#  'IIIIIYZYIIIXZY': -0.0017075134479304973j,
#  'IIIIIXZYIIIXZX': -0.0017075134479304973j,
#  'IIIIIXZXIIIXZY': 0.0017075134479304973j,
#  'IIIIIXXIIIYZZX': 0.0008537567239652486j,
#  'IIIIIYXIIIYZZY': 0.0008537567239652486j,
#  'IIIIIYYIIIYZZX': -0.0008537567239652486j,
#  'IIIIIXYIIIYZZY': 0.0008537567239652486j,
#  'IIIIIYXIIIXZZX': -0.0008537567239652486j,
#  'IIIIIXXIIIXZZY': 0.0008537567239652486j,
#  'IIIIIXYIIIXZZX': -0.0008537567239652486j,
#  'IIIIIYYIIIXZZY': -0.0008537567239652486j,
#  'IIIIXZZXIIIYXI': 0.0008537567239652486j,
#  'IIIIYZZXIIIYYI': 0.0008537567239652486j,
#  'IIIIYZZYIIIYXI': -0.0008537567239652486j,
#  'IIIIXZZYIIIYYI': 0.0008537567239652486j,
#  'IIIIYZZXIIIXXI': -0.0008537567239652486j,
#  'IIIIXZZXIIIXYI': 0.0008537567239652486j,
#  'IIIIXZZYIIIXXI': -0.0008537567239652486j,
#  'IIIIYZZYIIIXYI': -0.0008537567239652486j}

# %%
from qreduce.utils import *

# %%
build_symplectic_matrix(ham.keys())
# Out:
# array([[0, 0, 0, 0],
#        [1, 1, 0, 0],
#        [1, 1, 1, 1],
#        [0, 0, 1, 1]])

# %%
symplectic_hamiltonian(ham)
# Out:
# (array([[0, 0, 0, 0],
#         [1, 1, 0, 0],
#         [1, 1, 1, 1],
#         [0, 0, 1, 1]]),
#  array([[1],
#         [1],
#         [1],
#         [1]]))

# %%
b
# Out:
# array([[1. ],
#        [1. ],
#        [0.5],
#        [1. ]])
